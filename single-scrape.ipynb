# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
df1 = df1.rename(columns={'Left.1': 'club_involved_name'})
        df1 = df1.rename(columns={'Joined.1': 'club_involved_name'})
        appendData.append(df1)
# Out:
#           Joined.1           player_name Age            Position Pos  \
# 0              NaN          Jakub Kiwior  22         Centre-Back  CB
# 1              NaN      Leandro Trossard  28         Left Winger  LW
# 2              NaN              Jorginho  31  Defensive Midfield  DM
# 0          Norwich            Marquinhos  19        Right Winger  RW
# 1   Crystal Palace  Albert Sambi Lokonga  23    Central Midfield  CM
# ..             ...                   ...  ..                 ...  ..
# 4    PSV Eindhoven           Fábio Silva  20      Centre-Forward  CF
# 5          Benfica        Gonçalo Guedes  26         Left Winger  LW
# 6       Stoke City        Ki-Jana Hoever  21          Right-Back  RB
# 7       Cincinnati       Yerson Mosquera  21         Centre-Back  CB
# 8       Stoke City         Matija Sarkic  25          Goalkeeper  GK
#
#    Market value         Left.1            Fee transfer_movement fee_cleaned
# 0       €25.00m  Spezia Calcio        €25.00m                In     €25.00m
# 1       €35.00m       Brighton        €24.00m                In     €24.00m
# 2       €25.00m        Chelsea        €11.30m                In     €11.30m
# 0       €12.00m            NaN  loan transfer               Out         NaN
# 1       €15.00m            NaN  loan transfer               Out         NaN
# ..          ...            ...            ...               ...         ...
# 4       €13.00m            NaN  loan transfer               Out         NaN
# 5       €23.00m            NaN  loan transfer               Out         NaN
# 6        €3.50m            NaN  loan transfer               Out         NaN
# 7        €3.00m            NaN  loan transfer               Out         NaN
# 8        €2.00m            NaN  loan transfer               Out         NaN
#
# [184 rows x 10 columns]
